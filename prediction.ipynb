# %% [markdown]
# # Prediction Manual Check

# %%
import joblib
import json
from pandas import json_normalize

# %%
#checkout sample data
with open('sample.json') as f:
    sample_data = json.load(f)

sample_data
# Out:
# {'age': 0.8873995349,
#  'bmi': -0.3357034756,
#  'elective_surgery': 0.0,
#  'height': -0.943723452,
#  'pre_icu_los_days': 0.1394216503,
#  'weight': -0.7051467725,
#  'apache_2_diagnosis': -0.946091071,
#  'apache_3j_diagnosis': -0.8243602596,
#  'apache_post_operative': 0.0,
#  'arf_apache': 0.0,
#  'bun_apache': -0.9058206439,
#  'creatinine_apache': -0.7469095858,
#  'gcs_eyes_apache': -3.0273436805,
#  'gcs_motor_apache': -2.2540725276,
#  'gcs_unable_apache': -0.0231078803,
#  'gcs_verbal_apache': -2.6406044885,
#  'glucose_apache': -0.1492059984,
#  'heart_rate_apache': 0.6903936958,
#  'hematocrit_apache': 0.6141044185,
#  'intubated_apache': 0.0,
#  'map_apache': -1.2190441991,
#  'resprate_apache': 0.0844951027,
#  'sodium_apache': 1.5620177473,
#  'temp_apache': -1.6039055861,
#  'ventilated_apache': 1.0,
#  'wbc_apache': 0.1903910759,
#  'aids': 0.0,
#  'cirrhosis': 0.0,
#  'hepatic_failure': 0.0,
#  'immunosuppression': 0.0,
#  'leukemia': 0.0,
#  'lymphoma': 0.0,
# ...

# %%
#Model input needs to be in dataframe format
X_new = json_normalize([sample_data])
X_new
# Out:
#       age       bmi  elective_surgery    height  pre_icu_los_days    weight  \
# 0  0.8874 -0.335703               0.0 -0.943723          0.139422 -0.705147
#
#    apache_2_diagnosis  apache_3j_diagnosis  apache_post_operative  arf_apache  \
# 0           -0.946091             -0.82436                    0.0         0.0
#
#    ...  gender_M  icu_stay_type_readmit  icu_stay_type_transfer  \
# 0  ...       0.0                    0.0                     0.0
#
#    icu_admit_source_Floor  icu_admit_source_Operating Room / Recovery  \
# 0                     1.0                                         0.0
#
#    icu_admit_source_Other Hospital  icu_admit_source_Other ICU  \
# 0                              0.0                         0.0
#
#    hospital_admit_source_te  ethnicity_te  icu_type_te
# 0                  0.874753     -0.312151    -0.617037
#
# [1 rows x 43 columns]

# %%
#Read model
model = joblib.load("model_rf.pickle")

# %%
prediction = model.predict(X_new)
prediction
# Out:
# [Parallel(n_jobs=10)]: Using backend ThreadingBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 180 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 430 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=10)]: Done 500 out of 500 | elapsed:    0.0s finished
#     class_0   class_1
# 0  0.502655  0.497345

# %%
#for return
prediction.iloc[0,1]
# Out:
# np.float64(0.49734508140402656)
